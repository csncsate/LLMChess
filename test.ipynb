# %%
import sys
sys.path.insert(0, '/content/chess_exam')
sys.path.insert(0, '/content/LLMChess')

# %%
# !git clone https://github.com/csncsate/LLMChess.git
# %cd LLMChess
# !pip install -r requirements.txt
# Out:
# Cloning into 'LLMChess'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 19 (delta 2), reused 4 (delta 1), pack-reused 12 (from 1)
# Receiving objects: 100% (19/19), 13.77 KiB | 13.77 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/chess_exam/LLMChess/LLMChess
# ...

# %%
# !git clone https://github.com/bylinina/chess_exam.git
# !pip install -e chess_exam
# Out:
# Cloning into 'chess_exam'...
# remote: Enumerating objects: 150, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 150 (delta 31), reused 3 (delta 3), pack-reused 94 (from 1)
# Receiving objects: 100% (150/150), 54.19 KiB | 924.00 KiB/s, done.
# Resolving deltas: 100% (68/68), done.
# Obtaining file:///content/chess_exam/LLMChess/LLMChess/chess_exam
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: chess_tournament
#     Found existing installation: chess_tournament 0.1.0
#     Uninstalling chess_tournament-0.1.0:
#       Successfully uninstalled chess_tournament-0.1.0
#   Running setup.py develop for chess_tournament
# ...

# %%
from chess_tournament import Game, RandomPlayer, EnginePlayer
from player import TransformerPlayer

# %%
my_player = TransformerPlayer("LLMChess")
random_player = RandomPlayer("Random")

random1 = RandomPlayer("Random-1")
random2 = RandomPlayer("Random-2")

# %%
game = Game(random1, my_player, max_half_moves=50)
game.play(log_moves=True)
# Out:
# [LLMChess] Loading csncsate/LLMChess on cuda...
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# PLY 000 | LLMChess | white | rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1 | h2h4 | fallback:False
# PLY 001 | Random-1 | black | rnbqkbnr/pppppppp/8/8/7P/8/PPPPPPP1/RNBQKBNR b KQkq - 0 1 | g8h6 | fallback:False
# [LLMChess] Loading csncsate/LLMChess on cuda...
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# PLY 002 | LLMChess | white | rnbqkb1r/pppppppp/7n/8/7P/8/PPPPPPP1/RNBQKBNR w KQkq - 1 2 | h1h2 | fallback:False
# PLY 003 | Random-1 | black | rnbqkb1r/pppppppp/7n/8/7P/8/PPPPPPPR/RNBQKBN1 b Qkq - 2 2 | b7b5 | fallback:False
# [LLMChess] Loading csncsate/LLMChess on cuda...
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# PLY 004 | LLMChess | white | rnbqkb1r/p1pppppp/7n/1p6/7P/8/PPPPPPPR/RNBQKBN1 w Qkq - 0 3 | g2g4 | fallback:False
# ...
